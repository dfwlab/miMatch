# %%
import os
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import gridspec
import matplotlib.lines as mlines
from matplotlib.font_manager import FontProperties
import seaborn as sns
from scipy.stats import norm, pearsonr, spearmanr
import scipy.stats as stats
from scipy.spatial import distance
from sklearn.feature_selection import VarianceThreshold
import cloudpickle as pickle
import warnings
warnings.filterwarnings("ignore")

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all' #last_expr

# %% [markdown]
# # Download and normalization

# %%
def load_project(project):
    metadata = pd.read_csv('../Data/'+project[0]+'_'+project[1]+'_META.txt', sep='\t', index_col=0)
    microbiome = pd.read_csv('../Data/'+project[0]+'_'+project[1]+'_Relative.txt', sep='\t', index_col=0).T
    pathway = pd.read_csv('../Data/'+project[0]+'_'+project[1]+'_Pathway.txt', sep='\t', index_col=0).T
  
    metadata = metadata.loc[(metadata['study_condition']==project[2])|(metadata['study_condition']==project[3]), :]
    microbiome = microbiome.loc[metadata.sample_id, [i for i in microbiome.columns if 's__' in i and '|t__' not in i]]
    pathway = pathway.loc[metadata.sample_id, [i for i in pathway.columns if '|' not in i]]
    ### Normalize
    #microbiome = normalize(microbiome)
    #pathway = normalize(pathway)
    return metadata, microbiome, pathway

def normalize(data, zero_threshold=1e-8, zero_ratio=0.5):
    ### 1. o delete
    data = data.loc[:, (data<zero_threshold).sum()/float(data.shape[0])<zero_ratio]
    return data

# %% [markdown]
# # Read file

# %%
#dir_str=r"../Data/CMD/"  
#file_name=os.listdir(dir_str)
#file_dir=[os.path.join(dir_str,x) for x in file_name]
#file_dir

# %%
#for filename in file_name: 
#    if "2021-03-31" in filename:
#        newname = filename.replace('2021-03-31.', '')  
#    if "2021-04-02" in filename:
#        newname = filename.replace('2021-04-02.', '')  
#    if "2021-10-14" in filename: 
#        newname = filename.replace('2021-10-14.', '')
#    if "2022-04-13" in filename: 
#        newname = filename.replace('2022-04-13.', '')
#    if not(os.path.exists('../Data/'+newname)):
#        os.rename('../Data/CMD/'+filename, '../Data/'+newname)
#

# %%
dir_str=r"../Data/" 
file_name=os.listdir(dir_str)
file_dir=[os.path.join(dir_str,x) for x in file_name]
file_dir
# Out:
# ['../Data/.Rhistory',
#  '../Data/AsnicarF_2017_milk_META.txt',
#  '../Data/AsnicarF_2017_milk_Pathway.txt',
#  '../Data/AsnicarF_2017_milk_Relative.txt',
#  '../Data/AsnicarF_2017_stool_META.txt',
#  '../Data/AsnicarF_2017_stool_Pathway.txt',
#  '../Data/AsnicarF_2017_stool_Relative.txt',
#  '../Data/AsnicarF_2021_stool_META.txt',
#  '../Data/AsnicarF_2021_stool_Pathway.txt',
#  '../Data/AsnicarF_2021_stool_Relative.txt',
#  '../Data/BackhedF_2015_stool_META.txt',
#  '../Data/BackhedF_2015_stool_Pathway.txt',
#  '../Data/BackhedF_2015_stool_Relative.txt',
#  '../Data/Bengtsson-PalmeJ_2015_stool_META.txt',
#  '../Data/Bengtsson-PalmeJ_2015_stool_Pathway.txt',
#  '../Data/Bengtsson-PalmeJ_2015_stool_Relative.txt',
#  '../Data/BritoIL_2016_oralcavity_META.txt',
#  '../Data/BritoIL_2016_oralcavity_Pathway.txt',
#  '../Data/BritoIL_2016_oralcavity_Relative.txt',
#  '../Data/BritoIL_2016_stool_META.txt',
#  '../Data/BritoIL_2016_stool_Pathway.txt',
#  '../Data/BritoIL_2016_stool_Relative.txt',
#  '../Data/BrooksB_2017_stool_META.txt',
#  '../Data/BrooksB_2017_stool_Pathway.txt',
#  '../Data/BrooksB_2017_stool_Relative.txt',
#  '../Data/Castro-NallarE_2015_oralcavity_META.txt',
#  '../Data/Castro-NallarE_2015_oralcavity_Pathway.txt',
#  '../Data/Castro-NallarE_2015_oralcavity_Relative.txt',
#  '../Data/ChengpingW_2017_stool_META.txt',
#  '../Data/ChengpingW_2017_stool_Pathway.txt',
#  '../Data/ChengpingW_2017_stool_Relative.txt',
#  '../Data/ChngKR_2016_skin_META.txt',
#  '../Data/ChngKR_2016_skin_Pathway.txt',
#  '../Data/ChngKR_2016_skin_Relative.txt',
#  '../Data/ChuDM_2017_oralcavity_META.txt',
#  '../Data/ChuDM_2017_oralcavity_Pathway.txt',
#  '../Data/ChuDM_2017_oralcavity_Relative.txt',
#  '../Data/ChuDM_2017_stool_META.txt',
#  '../Data/ChuDM_2017_stool_Pathway.txt',
#  '../Data/ChuDM_2017_stool_Relative.txt',
#  '../Data/CosteaPI_2017_stool_META.txt',
#  '../Data/CosteaPI_2017_stool_Pathway.txt',
#  '../Data/CosteaPI_2017_stool_Relative.txt',
#  '../Data/DavidLA_2015_stool_META.txt',
#  '../Data/DavidLA_2015_stool_Pathway.txt',
#  '../Data/DavidLA_2015_stool_Relative.txt',
#  '../Data/DeFilippisF_2019_stool_META.txt',
#  '../Data/DeFilippisF_2019_stool_Pathway.txt',
#  '../Data/DeFilippisF_2019_stool_Relative.txt',
#  '../Data/DhakanDB_2019_stool_META.txt',
#  '../Data/DhakanDB_2019_stool_Pathway.txt',
#  '../Data/DhakanDB_2019_stool_Relative.txt',
#  '../Data/FengQ_2015_stool_META.txt',
#  '../Data/FengQ_2015_stool_Pathway.txt',
#  '../Data/FengQ_2015_stool_Relative.txt',
#  '../Data/FerrettiP_2018_oralcavity_META.txt',
#  '../Data/FerrettiP_2018_oralcavity_Pathway.txt',
#  '../Data/FerrettiP_2018_oralcavity_Relative.txt',
#  '../Data/FerrettiP_2018_skin_META.txt',
#  '../Data/FerrettiP_2018_skin_Pathway.txt',
#  '../Data/FerrettiP_2018_skin_Relative.txt',
#  '../Data/FerrettiP_2018_stool_META.txt',
#  '../Data/FerrettiP_2018_stool_Pathway.txt',
#  '../Data/FerrettiP_2018_stool_Relative.txt',
#  '../Data/FerrettiP_2018_vagina_META.txt',
#  '../Data/FerrettiP_2018_vagina_Pathway.txt',
#  '../Data/FerrettiP_2018_vagina_Relative.txt',
#  '../Data/FrankelAE_2017_stool_META.txt',
#  '../Data/FrankelAE_2017_stool_Pathway.txt',
#  '../Data/FrankelAE_2017_stool_Relative.txt',
#  '../Data/GhensiP_2019_oralcavity_META.txt',
#  '../Data/GhensiP_2019_oralcavity_Pathway.txt',
#  '../Data/GhensiP_2019_oralcavity_Relative.txt',
#  '../Data/GopalakrishnanV_2018_stool_META.txt',
#  '../Data/GopalakrishnanV_2018_stool_Pathway.txt',
#  '../Data/GopalakrishnanV_2018_stool_Relative.txt',
#  '../Data/GuptaA_2019_stool_META.txt',
#  '../Data/GuptaA_2019_stool_Pathway.txt',
#  '../Data/GuptaA_2019_stool_Relative.txt',
#  '../Data/HallAB_2017_stool_META.txt',
#  '../Data/HallAB_2017_stool_Pathway.txt',
#  '../Data/HallAB_2017_stool_Relative.txt',
#  '../Data/HanniganGD_2017_stool_META.txt',
#  '../Data/HanniganGD_2017_stool_Pathway.txt',
#  '../Data/HanniganGD_2017_stool_Relative.txt',
#  '../Data/HansenLBS_2018_stool_META.txt',
#  '../Data/HansenLBS_2018_stool_Pathway.txt',
#  '../Data/HansenLBS_2018_stool_Relative.txt',
#  '../Data/Heitz-BuschartA_2016_stool_META.txt',
#  '../Data/Heitz-BuschartA_2016_stool_Pathway.txt',
#  '../Data/Heitz-BuschartA_2016_stool_Relative.txt',
#  '../Data/HMP_2012_nasalcavity_META.txt',
#  '../Data/HMP_2012_nasalcavity_Pathway.txt',
#  '../Data/HMP_2012_nasalcavity_Relative.txt',
#  '../Data/HMP_2012_oralcavity_META.txt',
#  '../Data/HMP_2012_oralcavity_Pathway.txt',
#  '../Data/HMP_2012_oralcavity_Relative.txt',
#  '../Data/HMP_2012_skin_META.txt',
#  '../Data/HMP_2012_skin_Pathway.txt',
#  '../Data/HMP_2012_skin_Relative.txt',
#  '../Data/HMP_2012_stool_META.txt',
#  '../Data/HMP_2012_stool_Pathway.txt',
#  '../Data/HMP_2012_stool_Relative.txt',
#  '../Data/HMP_2012_vagina_META.txt',
#  '../Data/HMP_2012_vagina_Pathway.txt',
#  '../Data/HMP_2012_vagina_Relative.txt',
#  '../Data/HMP_2019_ibdmdb_stool_META.txt',
#  '../Data/HMP_2019_ibdmdb_stool_Pathway.txt',
#  '../Data/HMP_2019_ibdmdb_stool_Relative.txt',
#  '../Data/HMP_2019_t2d_stool_META.txt',
#  '../Data/HMP_2019_t2d_stool_Pathway.txt',
#  '../Data/HMP_2019_t2d_stool_Relative.txt',
#  '../Data/IjazUZ_2017_stool_META.txt',
#  '../Data/IjazUZ_2017_stool_Pathway.txt',
#  '../Data/IjazUZ_2017_stool_Relative.txt',
#  '../Data/JieZ_2017_stool_META.txt',
#  '../Data/JieZ_2017_stool_Pathway.txt',
#  '../Data/JieZ_2017_stool_Relative.txt',
#  '../Data/KarlssonFH_2013_stool_META.txt',
#  '../Data/KarlssonFH_2013_stool_Pathway.txt',
#  '../Data/KarlssonFH_2013_stool_Relative.txt',
#  '../Data/KaurK_2020_stool_META.txt',
#  '../Data/KaurK_2020_stool_Pathway.txt',
#  '../Data/KaurK_2020_stool_Relative.txt',
#  '../Data/KeohaneDM_2020_stool_META.txt',
#  '../Data/KeohaneDM_2020_stool_Pathway.txt',
#  '../Data/KeohaneDM_2020_stool_Relative.txt',
#  '../Data/KieserS_2018_stool_META.txt',
#  '../Data/KieserS_2018_stool_Pathway.txt',
#  '../Data/KieserS_2018_stool_Relative.txt',
#  '../Data/KosticAD_2015_stool_META.txt',
#  '../Data/KosticAD_2015_stool_Pathway.txt',
#  '../Data/KosticAD_2015_stool_Relative.txt',
#  '../Data/LassalleF_2017_oralcavity_META.txt',
#  '../Data/LassalleF_2017_oralcavity_Pathway.txt',
#  '../Data/LassalleF_2017_oralcavity_Relative.txt',
#  '../Data/LeChatelierE_2013_stool_META.txt',
#  '../Data/LeChatelierE_2013_stool_Pathway.txt',
#  '../Data/LeChatelierE_2013_stool_Relative.txt',
#  '../Data/LifeLinesDeep_2016_stool_META.txt',
#  '../Data/LifeLinesDeep_2016_stool_Pathway.txt',
#  '../Data/LifeLinesDeep_2016_stool_Relative.txt',
#  '../Data/LiJ_2014_stool_META.txt',
#  '../Data/LiJ_2014_stool_Pathway.txt',
#  '../Data/LiJ_2014_stool_Relative.txt',
#  '../Data/LiJ_2017_stool_META.txt',
#  '../Data/LiJ_2017_stool_Pathway.txt',
#  '../Data/LiJ_2017_stool_Relative.txt',
#  '../Data/LiSS_2016_stool_META.txt',
#  '../Data/LiSS_2016_stool_Pathway.txt',
#  '../Data/LiSS_2016_stool_Relative.txt',
#  '../Data/LiuW_2016_stool_META.txt',
#  '../Data/LiuW_2016_stool_Pathway.txt',
#  '../Data/LiuW_2016_stool_Relative.txt',
#  '../Data/LokmerA_2019_stool_META.txt',
#  '../Data/LokmerA_2019_stool_Pathway.txt',
#  '../Data/LokmerA_2019_stool_Relative.txt',
#  '../Data/LomanNJ_2013_stool_META.txt',
#  '../Data/LomanNJ_2013_stool_Pathway.txt',
#  '../Data/LomanNJ_2013_stool_Relative.txt',
#  '../Data/LoombaR_2017_stool_META.txt',
#  '../Data/LoombaR_2017_stool_Pathway.txt',
#  '../Data/LoombaR_2017_stool_Relative.txt',
#  '../Data/LouisS_2016_stool_META.txt',
#  '../Data/LouisS_2016_stool_Pathway.txt',
#  '../Data/LouisS_2016_stool_Relative.txt',
#  '../Data/MatsonV_2018_stool_META.txt',
#  '../Data/MatsonV_2018_stool_Pathway.txt',
#  '../Data/MatsonV_2018_stool_Relative.txt',
#  '../Data/MehtaRS_2018_stool_META.txt',
#  '../Data/MehtaRS_2018_stool_Pathway.txt',
#  '../Data/MehtaRS_2018_stool_Relative.txt',
#  '../Data/NagySzakalD_2017_stool_META.txt',
#  '../Data/NagySzakalD_2017_stool_Pathway.txt',
#  '../Data/NagySzakalD_2017_stool_Relative.txt',
#  '../Data/NielsenHB_2014_stool_META.txt',
#  '../Data/NielsenHB_2014_stool_Pathway.txt',
#  '../Data/NielsenHB_2014_stool_Relative.txt',
#  '../Data/Obregon-TitoAJ_2015_stool_META.txt',
#  '../Data/Obregon-TitoAJ_2015_stool_Pathway.txt',
#  '../Data/Obregon-TitoAJ_2015_stool_Relative.txt',
#  '../Data/OhJ_2014_skin_META.txt',
#  '../Data/OhJ_2014_skin_Pathway.txt',
#  '../Data/OhJ_2014_skin_Relative.txt',
#  '../Data/OlmMR_2017_oralcavity_META.txt',
#  '../Data/OlmMR_2017_oralcavity_Pathway.txt',
#  '../Data/OlmMR_2017_oralcavity_Relative.txt',
#  '../Data/OlmMR_2017_skin_META.txt',
#  '../Data/OlmMR_2017_skin_Pathway.txt',
#  '../Data/OlmMR_2017_skin_Relative.txt',
#  '../Data/OlmMR_2017_stool_META.txt',
#  '../Data/OlmMR_2017_stool_Pathway.txt',
#  '../Data/OlmMR_2017_stool_Relative.txt',
#  '../Data/PasolliE_2019_stool_META.txt',
#  '../Data/PasolliE_2019_stool_Pathway.txt',
#  '../Data/PasolliE_2019_stool_Relative.txt',
#  '../Data/PehrssonE_2016_stool_META.txt',
#  '../Data/PehrssonE_2016_stool_Pathway.txt',
#  '../Data/PehrssonE_2016_stool_Relative.txt',
#  '../Data/PetersBA_2019_stool_META.txt',
#  '../Data/PetersBA_2019_stool_Pathway.txt',
#  '../Data/PetersBA_2019_stool_Relative.txt',
#  '../Data/QinJ_2012_stool_META.txt',
#  '../Data/QinJ_2012_stool_Pathway.txt',
#  '../Data/QinJ_2012_stool_Relative.txt',
#  '../Data/QinN_2014_stool_META.txt',
#  '../Data/QinN_2014_stool_Pathway.txt',
#  '../Data/QinN_2014_stool_Relative.txt',
#  '../Data/RampelliS_2015_stool_META.txt',
#  '../Data/RampelliS_2015_stool_Pathway.txt',
#  '../Data/RampelliS_2015_stool_Relative.txt',
#  '../Data/RaymondF_2016_stool_META.txt',
#  '../Data/RaymondF_2016_stool_Pathway.txt',
#  '../Data/RaymondF_2016_stool_Relative.txt',
#  '../Data/RosaBA_2018_stool_META.txt',
#  '../Data/RosaBA_2018_stool_Pathway.txt',
#  '../Data/RosaBA_2018_stool_Relative.txt',
#  '../Data/RubelMA_2020_stool_META.txt',
#  '../Data/RubelMA_2020_stool_Pathway.txt',
#  '../Data/RubelMA_2020_stool_Relative.txt',
#  '../Data/SankaranarayananK_2015_stool_META.txt',
#  '../Data/SankaranarayananK_2015_stool_Pathway.txt',
#  '../Data/SankaranarayananK_2015_stool_Relative.txt',
#  '../Data/ShaoY_2019_stool_META.txt',
#  '../Data/ShaoY_2019_stool_Pathway.txt',
#  '../Data/ShaoY_2019_stool_Relative.txt',
#  '../Data/ShiB_2015_oralcavity_META.txt',
#  '../Data/ShiB_2015_oralcavity_Pathway.txt',
#  '../Data/ShiB_2015_oralcavity_Relative.txt',
#  '../Data/SmitsSA_2017_stool_META.txt',
#  '../Data/SmitsSA_2017_stool_Pathway.txt',
#  '../Data/SmitsSA_2017_stool_Relative.txt',
#  '../Data/TettAJ_2016_skin_META.txt',
#  '../Data/TettAJ_2016_skin_Pathway.txt',
#  '../Data/TettAJ_2016_skin_Relative.txt',
#  '../Data/TettAJ_2019_a_stool_META.txt',
#  '../Data/TettAJ_2019_a_stool_Pathway.txt',
#  '../Data/TettAJ_2019_a_stool_Relative.txt',
#  '../Data/TettAJ_2019_b_stool_META.txt',
#  '../Data/TettAJ_2019_b_stool_Pathway.txt',
#  '../Data/TettAJ_2019_b_stool_Relative.txt',
#  '../Data/TettAJ_2019_c_stool_META.txt',
#  '../Data/TettAJ_2019_c_stool_Pathway.txt',
#  '../Data/TettAJ_2019_c_stool_Relative.txt',
#  '../Data/ThomasAM_2018a_stool_META.txt',
#  '../Data/ThomasAM_2018a_stool_Pathway.txt',
#  '../Data/ThomasAM_2018a_stool_Relative.txt',
#  '../Data/ThomasAM_2018b_stool_META.txt',
#  '../Data/ThomasAM_2018b_stool_Pathway.txt',
#  '../Data/ThomasAM_2018b_stool_Relative.txt',
#  '../Data/ThomasAM_2019_c_stool_META.txt',
#  '../Data/ThomasAM_2019_c_stool_Pathway.txt',
#  '../Data/ThomasAM_2019_c_stool_Relative.txt',
#  '../Data/VatanenT_2016_stool_META.txt',
#  '../Data/VatanenT_2016_stool_Pathway.txt',
#  '../Data/VatanenT_2016_stool_Relative.txt',
#  '../Data/VilaAV_2018_stool_META.txt',
#  '../Data/VilaAV_2018_stool_Pathway.txt',
#  '../Data/VilaAV_2018_stool_Relative.txt',
#  '../Data/VincentC_2016_stool_META.txt',
#  '../Data/VincentC_2016_stool_Pathway.txt',
#  '../Data/VincentC_2016_stool_Relative.txt',
#  '../Data/VogtmannE_2016_stool_META.txt',
#  '../Data/VogtmannE_2016_stool_Pathway.txt',
#  '../Data/VogtmannE_2016_stool_Relative.txt',
#  '../Data/WampachL_2018_stool_META.txt',
#  '../Data/WampachL_2018_stool_Pathway.txt',
#  '../Data/WampachL_2018_stool_Relative.txt',
#  '../Data/WampachL_2018_vagina_META.txt',
#  '../Data/WampachL_2018_vagina_Pathway.txt',
#  '../Data/WampachL_2018_vagina_Relative.txt',
#  '../Data/WindTT_2020_stool_META.txt',
#  '../Data/WindTT_2020_stool_Pathway.txt',
#  '../Data/WindTT_2020_stool_Relative.txt',
#  '../Data/WirbelJ_2018_stool_META.txt',
#  '../Data/WirbelJ_2018_stool_Pathway.txt',
#  '../Data/WirbelJ_2018_stool_Relative.txt',
#  '../Data/XieH_2016_stool_META.txt',
#  '../Data/XieH_2016_stool_Pathway.txt',
#  '../Data/XieH_2016_stool_Relative.txt',
#  '../Data/YachidaS_2019_stool_META.txt',
#  '../Data/YachidaS_2019_stool_Pathway.txt',
#  '../Data/YachidaS_2019_stool_Relative.txt',
#  '../Data/YassourM_2016_stool_META.txt',
#  '../Data/YassourM_2016_stool_Pathway.txt',
#  '../Data/YassourM_2016_stool_Relative.txt',
#  '../Data/YassourM_2018_stool_META.txt',
#  '../Data/YassourM_2018_stool_Pathway.txt',
#  '../Data/YassourM_2018_stool_Relative.txt',
#  '../Data/YeZ_2018_stool_META.txt',
#  '../Data/YeZ_2018_stool_Pathway.txt',
#  '../Data/YeZ_2018_stool_Relative.txt',
#  '../Data/YuJ_2015_stool_META.txt',
#  '../Data/YuJ_2015_stool_Pathway.txt',
#  '../Data/YuJ_2015_stool_Relative.txt',
#  '../Data/ZeeviD_2015_stool_META.txt',
#  '../Data/ZeeviD_2015_stool_Pathway.txt',
#  '../Data/ZeeviD_2015_stool_Relative.txt',
#  '../Data/ZellerG_2014_stool_META.txt',
#  '../Data/ZellerG_2014_stool_Pathway.txt',
#  '../Data/ZellerG_2014_stool_Relative.txt',
#  '../Data/ZhuF_2020_stool_META.txt',
#  '../Data/ZhuF_2020_stool_Pathway.txt',
#  '../Data/ZhuF_2020_stool_Relative.txt']

# %% [markdown]
# # load dictionary

# %%
projects=pd.read_csv('../Label/fenzu.csv',index_col=0).T
projects=projects.to_dict('list')
projects
# Out:
# {'1': ['AsnicarF_2017', 'milk', 'control', nan],
#  '2': ['AsnicarF_2017', 'stool', 'control', nan],
#  '3': ['AsnicarF_2021', 'stool', 'control', nan],
#  '4': ['BackhedF_2015', 'stool', 'control', nan],
#  '5': ['Bengtsson-PalmeJ_2015', 'stool', 'control', nan],
#  '6': ['BritoIL_2016', 'oralcavity', 'control', nan],
#  '7': ['BritoIL_2016', 'stool', 'control', nan],
#  '8': ['BrooksB_2017', 'stool', 'control', 'premature_born'],
#  '9': ['Castro-NallarE_2015', 'oralcavity', 'control', 'schizofrenia'],
#  '10': ['ChengpingW_2017', 'stool', 'AS', nan],
#  '11': ['ChngKR_2016', 'skin', 'control', 'AD'],
#  '12': ['ChuDM_2017', 'oralcavity', 'control', nan],
#  '13': ['ChuDM_2017', 'stool', 'control', nan],
#  '14': ['CosteaPI_2017', 'stool', 'control', nan],
#  '15': ['DavidLA_2015', 'stool', 'control', 'acute_diarrhoea'],
#  '16': ['DeFilippisF_2019', 'stool', 'control', nan],
#  '17': ['DhakanDB_2019', 'stool', 'control', nan],
#  '18_1': ['FengQ_2015', 'stool', 'control', 'adenoma'],
#  '18_2': ['FengQ_2015', 'stool', 'control', 'CRC'],
#  '18_3': ['FengQ_2015', 'stool', 'CRC', 'adenoma'],
#  '19': ['FerrettiP_2018', 'oralcavity', 'control', nan],
#  '20': ['FerrettiP_2018', 'skin', 'control', nan],
#  '21': ['FerrettiP_2018', 'stool', 'control', nan],
#  '22': ['FerrettiP_2018', 'vagina', 'control', nan],
#  '23': ['FrankelAE_2017', 'stool', 'melanoma', nan],
#  '24_1': ['GhensiP_2019', 'oralcavity', 'control', 'mucositis'],
#  '24_2': ['GhensiP_2019', 'oralcavity', 'mucositis', 'peri-implantitis'],
#  '24_3': ['GhensiP_2019', 'oralcavity', 'control', 'peri-implantitis'],
#  '25': ['GopalakrishnanV_2018', 'stool', 'melanoma', nan],
#  '26': ['GuptaA_2019', 'stool', 'control', 'CRC'],
#  '27': ['HallAB_2017', 'stool', 'control', 'IBD'],
#  '28_1': ['HanniganGD_2017', 'stool', 'control', 'adenoma'],
#  '28_2': ['HanniganGD_2017', 'stool', 'control', 'CRC'],
#  '28_3': ['HanniganGD_2017', 'stool', 'CRC', 'adenoma'],
#  '29': ['HansenLBS_2018', 'stool', 'control', nan],
#  '30': ['Heitz-BuschartA_2016', 'stool', 'control', 'T1D'],
#  '31': ['HMP_2012', 'nasalcavity', 'control', nan],
#  '32': ['HMP_2012', 'oralcavity', 'control', nan],
#  '33': ['HMP_2012', 'skin', 'control', nan],
#  '34': ['HMP_2012', 'stool', 'control', nan],
#  '35': ['HMP_2012', 'vagina', 'control', nan],
#  '36': ['HMP_2019_ibdmdb', 'stool', 'control', 'IBD'],
#  '37_1': ['HMP_2019_t2d', 'stool', 'control', 'IGT'],
#  '37_2': ['HMP_2019_t2d', 'stool', 'IGT', 'T2D'],
#  '37_3': ['HMP_2019_t2d', 'stool', 'control', 'T2D'],
#  '38': ['IjazUZ_2017', 'stool', 'control', 'IBD'],
#  '39': ['JieZ_2017', 'stool', 'control', 'ACVD'],
#  '40_1': ['KarlssonFH_2013', 'stool', 'control', 'IGT'],
#  '40_2': ['KarlssonFH_2013', 'stool', 'IGT', 'T2D'],
#  '40_3': ['KarlssonFH_2013', 'stool', 'control', 'T2D'],
#  '41': ['KaurK_2020', 'stool', 'control', nan],
#  '42': ['KeohaneDM_2020', 'stool', 'control', nan],
#  '43': ['KieserS_2018', 'stool', 'control', 'acute_diarrhoea'],
#  '44': ['KosticAD_2015', 'stool', 'control', 'T1D'],
#  '45': ['LassalleF_2017', 'oralcavity', 'control', nan],
#  '46': ['LeChatelierE_2013', 'stool', 'control', nan],
#  '47': ['LifeLinesDeep_2016', 'stool', 'control', nan],
#  '48_1': ['LiJ_2014', 'stool', 'control', 'IBD'],
#  '48_2': ['LiJ_2014', 'stool', 'IBD', 'T1D'],
#  '48_3': ['LiJ_2014', 'stool', 'IBD', 'T2D'],
#  '48_4': ['LiJ_2014', 'stool', 'T1D', 'T2D'],
#  '48_5': ['LiJ_2014', 'stool', 'control', 'T1D'],
#  '48_6': ['LiJ_2014', 'stool', 'control', 'T2D'],
#  '49_1': ['LiJ_2017', 'stool', 'control', 'hypertension'],
#  '49_2': ['LiJ_2017', 'stool', 'hypertension', 'pre-hypertension'],
#  '49_3': ['LiJ_2017', 'stool', 'control', 'pre-hypertension'],
#  '50_1': ['LiSS_2016', 'stool', 'control', 'FMT'],
#  '50_2': ['LiSS_2016', 'stool', 'FMT', 'metabolic_syndrome'],
#  '50_3': ['LiSS_2016', 'stool', 'control', 'metabolic_syndrome'],
#  '51': ['LiuW_2016', 'stool', 'control', nan],
#  '52': ['LokmerA_2019', 'stool', 'control', nan],
#  '53': ['LomanNJ_2013', 'stool', 'STEC', nan],
#  '54_1': ['LoombaR_2017', 'stool', 'control', 'cirrhosis'],
#  '54_2': ['LoombaR_2017', 'stool', 'control', 'fatty_liver'],
#  '54_3': ['LoombaR_2017', 'stool', 'fatty_liver', 'cirrhosis'],
#  '55': ['LouisS_2016', 'stool', 'control', nan],
#  '56': ['MatsonV_2018', 'stool', 'melanoma', nan],
#  '57': ['MehtaRS_2018', 'stool', 'control', nan],
#  '58': ['NagySzakalD_2017', 'stool', 'control', 'ME/CFS'],
#  '59': ['NielsenHB_2014', 'stool', 'control', 'IBD'],
#  '60': ['Obregon-TitoAJ_2015', 'stool', 'control', nan],
#  '61': ['OhJ_2014', 'skin', 'control', nan],
#  '62': ['OlmMR_2017', 'oralcavity', 'premature_born', nan],
#  '63': ['OlmMR_2017', 'skin', 'premature_born', nan],
#  '64': ['OlmMR_2017', 'stool', 'premature_born', nan],
#  '65': ['PasolliE_2019', 'stool', 'control', nan],
#  '66': ['PehrssonE_2016', 'stool', 'control', nan],
#  '67': ['PetersBA_2019', 'stool', 'melanoma', nan],
#  '68': ['QinJ_2012', 'stool', 'control', 'T2D'],
#  '69': ['QinN_2014', 'stool', 'control', 'cirrhosis'],
#  '70': ['RampelliS_2015', 'stool', 'control', nan],
#  '71': ['RaymondF_2016', 'stool', 'control', 'cephalosporins'],
#  '72': ['RosaBA_2018', 'stool', 'control', 'STH'],
#  '73': ['RubelMA_2020', 'stool', 'control', 'STH'],
#  '74': ['SankaranarayananK_2015', 'stool', 'control', 'T2D'],
#  '75': ['ShaoY_2019', 'stool', 'control', nan],
#  '76': ['ShiB_2015', 'oralcavity', 'periodontitis', 'SRP'],
#  '77': ['SmitsSA_2017', 'stool', 'control', nan],
#  '78': ['TettAJ_2016', 'skin', 'control', 'psoriasis'],
#  '79': ['TettAJ_2019_a', 'stool', 'control', nan],
#  '80': ['TettAJ_2019_c', 'stool', 'control', nan],
#  '81_1': ['ThomasAM_2018a', 'stool', 'control', 'adenoma'],
#  '81_2': ['ThomasAM_2018a', 'stool', 'control', 'CRC'],
#  '81_3': ['ThomasAM_2018a', 'stool', 'CRC', 'adenoma'],
#  '82': ['ThomasAM_2018b', 'stool', 'control', 'CRC'],
#  '83': ['ThomasAM_2019_c', 'stool', 'control', 'CRC'],
#  '84_1': ['VatanenT_2016', 'stool', 'control', 'bronchitis'],
#  '84_2': ['VatanenT_2016', 'stool', 'control', 'cough'],
#  '84_3': ['VatanenT_2016', 'stool', 'control', 'cystitis'],
#  '84_4': ['VatanenT_2016', 'stool', 'control', 'fever'],
#  '84_5': ['VatanenT_2016', 'stool', 'control', 'infectiousgastroenteritis'],
#  '84_6': ['VatanenT_2016', 'stool', 'control', 'NK'],
#  '84_7': ['VatanenT_2016', 'stool', 'control', 'otitis'],
#  '84_8': ['VatanenT_2016', 'stool', 'control', 'pneumonia'],
#  '84_9': ['VatanenT_2016', 'stool', 'control', 'pyelonefritis'],
#  '84_10': ['VatanenT_2016', 'stool', 'control', 'pyelonephritis'],
#  '84_11': ['VatanenT_2016', 'stool', 'control', 'respiratoryinf'],
#  '84_12': ['VatanenT_2016', 'stool', 'control', 'salmonellosis'],
#  '84_13': ['VatanenT_2016', 'stool', 'control', 'sepsis'],
#  '84_14': ['VatanenT_2016', 'stool', 'control', 'skininf'],
#  '84_15': ['VatanenT_2016', 'stool', 'control', 'stomatitis'],
#  '84_16': ['VatanenT_2016', 'stool', 'control', 'suspinf'],
#  '84_17': ['VatanenT_2016', 'stool', 'control', 'tonsillitis'],
#  '85': ['VilaAV_2018', 'stool', 'IBD', nan],
#  '86': ['VincentC_2016', 'stool', 'control', 'CDI'],
#  '87': ['VogtmannE_2016', 'stool', 'control', 'CRC'],
#  '88': ['WampachL_2018', 'stool', 'control', nan],
#  '89': ['WampachL_2018', 'vagina', 'control', nan],
#  '90': ['WindTT_2020', 'stool', 'melanoma', nan],
#  '91': ['WirbelJ_2018', 'stool', 'control', 'CRC'],
#  '92_1': ['XieH_2016', 'stool', 'control', 'asthma'],
#  '92_2': ['XieH_2016', 'stool', 'control', 'migraine'],
#  '92_3': ['XieH_2016', 'stool', 'migraine', 'asthma'],
#  '93_1': ['YachidaS_2019', 'stool', 'control', 'carcinoma_surgery_history'],
#  '93_2': ['YachidaS_2019', 'stool', 'control', 'adenoma'],
#  '93_3': ['YachidaS_2019', 'stool', 'control', 'CRC'],
#  '93_4': ['YachidaS_2019', 'stool', 'carcinoma_surgery_history', 'CRC'],
#  '93_5': ['YachidaS_2019', 'stool', 'carcinoma_surgery_history', 'adenoma'],
#  '93_6': ['YachidaS_2019', 'stool', 'CRC', 'adenoma'],
#  '94': ['YassourM_2016', 'stool', 'control', nan],
#  '95': ['YassourM_2018', 'stool', 'control', nan],
#  '96': ['YeZ_2018', 'stool', 'control', 'BD'],
#  '97': ['YuJ_2015', 'stool', 'control', 'CRC'],
#  '98': ['ZeeviD_2015', 'stool', 'control', nan],
#  '99_1': ['ZellerG_2014', 'stool', 'control', 'adenoma'],
#  '99_2': ['ZellerG_2014', 'stool', 'control', 'CRC'],
#  '99_3': ['ZellerG_2014', 'stool', 'CRC', 'adenoma'],
#  '100': ['ZhuF_2020', 'stool', 'control', 'schizofrenia'],
#  '101': ['TettAJ_2019_b', 'stool', 'control', nan]}

# %% [markdown]
# # miMatch

# %%
# %run miMatch.py

# %%
test()
# Out:
#     N Control  Mean Control  N Case  Mean Case  cohen's d  Fold change  \
# F1        100      5.041349     100   4.483199   0.560422     0.889286
# F2        100      1.919333     100   2.745474   0.791626     1.430431
# F3        100      2.938563     100   3.554254   0.674756     1.209521
#
#          p-value       fdr
# F1  1.545838e-04  0.000155
# F2  4.912068e-07  0.000001
# F3  9.921885e-06  0.000015
#     N Control  Mean Control  N Case  Mean Case  cohen's d  Fold change  \
# F1         98      4.458103      98   4.527594   0.073514     1.015588
# F2         98      2.527884      98   2.725603   0.209926     1.078215
# F3         98      3.680662      98   3.537779   0.153638     0.961180
#
#      p-value       fdr
# F1  0.548001  0.548001
# F2  0.310651  0.504858
# F3  0.336572  0.504858

# %%
def matched_result_check(sample_size, balance_stats):
    sample_check = (sample_size.loc['Matched', :]/sample_size.loc['All', :]).min()>=0.5
    p_check = balance_stats.loc[balance_stats['isMatch']=='matched', 'pvalue'].min()>0.05
    return sample_check, p_check

def select_params(selector):
    res = []
    k = 0
    for caliper, ratio, sample_size, balance_stats in selector:
        temp = list(balance_stats.loc[(balance_stats['isMatch']=='matched')&(balance_stats['feature']=='distance'), 'pvalue'])
        sample_check, p_check = matched_result_check(sample_size, balance_stats)
        res.append([k, temp[0], temp[1], temp[0]*temp[1], sample_check, p_check, sample_check and p_check])
        k += 1
    res = pd.DataFrame(res, columns=['index', 'p_ttest', 'p_wilcoxon', 'p_ttest*p_wilcoxon', 'Sample_check', 'P_check', 'Sample&P_check'])
    if res['Sample&P_check'].sum()>0:
        select_index = res.loc[res['Sample&P_check'], 'index']
        best_caliper, best_ratio, best_p = 0, 0, 0
        for i in select_index:
            if float(res.loc[res['index']==i, 'p_ttest*p_wilcoxon'])>=best_p:
                best_caliper, best_ratio, best_p = selector[i][0], selector[i][1], float(res.loc[res['index']==i, 'p_ttest*p_wilcoxon'])
    elif res['P_check'].sum()>0: 
        select_index = res.loc[res['P_check'], 'index']
        best_caliper, best_ratio, best_p = 0, 0, 0
        for i in select_index:
            if float(res.loc[res['index']==i, 'p_ttest*p_wilcoxon'])>=best_p:
                best_caliper, best_ratio, best_p = selector[i][0], selector[i][1], float(res.loc[res['index']==i, 'p_ttest*p_wilcoxon'])
    else:
        select_index = res['index']
        best_caliper, best_ratio, best_p = 0, 0, 0
        for i in select_index:
            if float(res.loc[res['index']==i, 'p_ttest*p_wilcoxon'])>=best_p:
                best_caliper, best_ratio, best_p = selector[i][0], selector[i][1], float(res.loc[res['index']==i, 'p_ttest*p_wilcoxon'])
    return best_caliper, best_ratio, best_p

# %%
ps_result = []
print(projects.keys())
for pi in project_bf.keys():
    project = projects[pi]
    if pd.isnull(project[2]) or pd.isnull(project[3]):
        continue
    metadata, microbiome, pathway = load_project(project)
    microbiome['Group'] = [0 if i == project[2] else 1 for i in metadata['study_condition']]
    pathway['Group'] = [0 if i == project[2] else 1 for i in metadata['study_condition']]
    ### select params
    selector = []
    for caliper, ratio in [(0.1, 1), (0.1, 2), (0.1, 3), (0.15, 1), (0.15, 2), (0.15, 3), 
                           (0.2, 1), (0.2, 2), (0.2, 3), (0.25, 1), (0.25, 2), (0.25, 3)]:
        try:
            params = [('output', 'output_dir', '../Temp/'+pi+'/'), ('psm', 'caliper', str(caliper)), ('psm', 'ratio', str(ratio))]
            sample_size, match_drop_unmatched, match, pairs, sum_matched, balance_stats = run_miMatch(pathway, target='Group', params=params, is_pca=True)
            sample_check, p_check = matched_result_check(sample_size, balance_stats)
            selector.append([caliper, ratio, sample_size, balance_stats])
        except:
            pass
    best_caliper, best_ratio, best_p = select_params(selector)
    
    ### run with best params
    params = [('output', 'output_dir', '../Temp/'+pi+'/'), ('psm', 'caliper', str(best_caliper)), ('psm', 'ratio', str(best_ratio))]
    sample_size, match_drop_unmatched, match, pairs, sum_matched, balance_stats = run_miMatch(pathway, target='Group', params=params, is_pca=True)
    print(pi, project[0], project[2], project[3], best_caliper, best_ratio, sample_check, p_check)
    ps_result.append([pi, project[0], project[2], project[3], best_caliper, best_ratio])
    
    ### difference microbiome
    result = pd.DataFrame()
    res = diff_by_rank_sum(microbiome, target='Group', features=[i for i in microbiome.columns if i!='Group'])
    res.columns = [i+'(raw)' for i in res.columns]
    result = pd.concat([result, res], axis=1, sort=False)
    res = diff_by_signed_rank(microbiome, pairs, features=[i for i in microbiome.columns if i!='Group'])
    res.columns = [i+'(PSM)' for i in res.columns]
    result = pd.concat([result, res], axis=1, sort=False)
    result = result.sort_values(['fdr(PSM)'])
    result.to_csv('../Temp/'+pi+'/'+'Microbiome_difference.csv')
    
    ### differential pathway
    result = pd.DataFrame()
    res = diff_by_rank_sum(pathway, target='Group', features=[i for i in pathway.columns if i!='Group'])
    res.columns = [i+'(raw)' for i in res.columns]
    result = pd.concat([result, res], axis=1, sort=False)
    res = diff_by_signed_rank(pathway, pairs, features=[i for i in pathway.columns if i!='Group'])
    res.columns = [i+'(PSM)' for i in res.columns]
    result = pd.concat([result, res], axis=1, sort=False)
    result = result.sort_values(['fdr(PSM)'])
    result.to_csv('../Temp/'+pi+'/'+'Pathway_difference.csv')
    
    ### raw data
    metadata.to_csv('../Temp/'+pi+'/'+'Metadata.csv')
    microbiome.to_csv('../Temp/'+pi+'/'+'Microbiome.csv')
    pathway.to_csv('../Temp/'+pi+'/'+'Pathway.csv')
    
ps_result = pd.DataFrame(ps_result, columns=['ID', 'Pname', 'PControl', 'PCase', 'Caliper', 'Ratio'])
ps_result.to_csv('../Temp/PSM_check(0.25_2).csv')
# Out:
# dict_keys(['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12', '13', '14', '15', '16', '17', '18_1', '18_2', '18_3', '19', '20', '21', '22', '23', '24_1', '24_2', '24_3', '25', '26', '27', '28_1', '28_2', '28_3', '29', '30', '31', '32', '33', '34', '35', '36', '37_1', '37_2', '37_3', '38', '39', '40_1', '40_2', '40_3', '41', '42', '43', '44', '45', '46', '47', '48_1', '48_2', '48_3', '48_4', '48_5', '48_6', '49_1', '49_2', '49_3', '50_1', '50_2', '50_3', '51', '52', '53', '54_1', '54_2', '54_3', '55', '56', '57', '58', '59', '60', '61', '62', '63', '64', '65', '66', '67', '68', '69', '70', '71', '72', '73', '74', '75', '76', '77', '78', '79', '80', '81_1', '81_2', '81_3', '82', '83', '84_1', '84_2', '84_3', '84_4', '84_5', '84_6', '84_7', '84_8', '84_9', '84_10', '84_11', '84_12', '84_13', '84_14', '84_15', '84_16', '84_17', '85', '86', '87', '88', '89', '90', '91', '92_1', '92_2', '92_3', '93_1', '93_2', '93_3', '93_4', '93_5', '93_6', '94', '95', '96', '97', '98', '99_1', '99_2', '99_3', '100', '101'])
# 97 YuJ_2015 control CRC 0.15 3 True True
# 99_1 ZellerG_2014 control adenoma 0.2 2 True True
# 99_2 ZellerG_2014 control CRC 0.25 1 True True
# 99_3 ZellerG_2014 CRC adenoma 0.1 3 True True
# 100 ZhuF_2020 control schizofrenia 0.15 2 True True
# 101 NagySzakalD_2017 control ME/CFS 0.15 3 True False

# %% [markdown]
# # test part

# %%
pi='08'
project = projects[pi]
metadata, microbiome, pathway = load_project(project)
microbiome['Group'] = [0 if i == project[2] else 1 for i in metadata['study_condition']]
pathway['Group'] = [0 if i == project[2] else 1 for i in metadata['study_condition']]
microbiome.head(2)
pathway.head(2)
# Out:
#               k__Bacteria|p__Proteobacteria|c__Gammaproteobacteria|o__Enterobacterales|f__Enterobacteriaceae|g__Klebsiella|s__Klebsiella_pneumoniae  \
# N2_031_008G1                                           71.74142
# N2_031_010G1                                           71.66040
#
#               k__Bacteria|p__Proteobacteria|c__Gammaproteobacteria|o__Enterobacterales|f__Enterobacteriaceae|g__Klebsiella|s__Klebsiella_variicola  \
# N2_031_008G1                                           19.43325
# N2_031_010G1                                           18.55608
#
#               k__Bacteria|p__Proteobacteria|c__Gammaproteobacteria|o__Enterobacterales|f__Enterobacteriaceae|g__Klebsiella|s__Klebsiella_quasipneumoniae  \
# N2_031_008G1                                            8.80403
# N2_031_010G1                                            9.77410
#
#               k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactobacillales|f__Streptococcaceae|g__Lactococcus|s__Lactococcus_lactis  \
# N2_031_008G1                                            0.01135
# N2_031_010G1                                            0.00000
#
#               k__Bacteria|p__Firmicutes|c__Bacilli|o__Bacillales|f__Staphylococcaceae|g__Staphylococcus|s__Staphylococcus_epidermidis  \
# N2_031_008G1                                            0.00995
# N2_031_010G1                                            0.00625
#
#               k__Bacteria|p__Proteobacteria|c__Gammaproteobacteria|o__Enterobacterales|f__Enterobacteriaceae|g__Escherichia|s__Escherichia_coli  \
# N2_031_008G1                                            0.00000
# N2_031_010G1                                            0.00317
#
#               k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactobacillales|f__Enterococcaceae|g__Enterococcus|s__Enterococcus_faecalis  \
# N2_031_008G1                                                0.0
# N2_031_010G1                                                0.0
#
#               k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactobacillales|f__Streptococcaceae|g__Streptococcus|s__Streptococcus_agalactiae  \
# N2_031_008G1                                                0.0
# N2_031_010G1                                                0.0
#
#               k__Bacteria|p__Firmicutes|c__Negativicutes|o__Veillonellales|f__Veillonellaceae|g__Veillonella|s__Veillonella_dispar  \
# N2_031_008G1                                                0.0
# N2_031_010G1                                                0.0
#
#               k__Bacteria|p__Firmicutes|c__Tissierellia|o__Tissierellales|f__Peptoniphilaceae|g__Finegoldia|s__Finegoldia_magna  \
# N2_031_008G1                                                0.0
# N2_031_010G1                                                0.0
#
#               ...  \
# N2_031_008G1  ...
# N2_031_010G1  ...
#
#               k__Bacteria|p__Proteobacteria|c__Gammaproteobacteria|o__Enterobacterales|f__Enterobacteriaceae|g__Kosakonia|s__Kosakonia_sp_S29  \
# N2_031_008G1                                                0.0
# N2_031_010G1                                                0.0
#
#               k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Actinomycetales|f__Actinomycetaceae|g__Actinomyces|s__Actinomyces_turicensis  \
# N2_031_008G1                                                0.0
# N2_031_010G1                                                0.0
#
#               k__Bacteria|p__Firmicutes|c__Bacilli|o__Lactobacillales|f__Enterococcaceae|g__Enterococcus|s__Enterococcus_hirae  \
# N2_031_008G1                                                0.0
# N2_031_010G1                                                0.0
#
#               k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Corynebacteriales|f__Corynebacteriaceae|g__Corynebacterium|s__Corynebacterium_glucuronolyticum  \
# N2_031_008G1                                                0.0
# N2_031_010G1                                                0.0
#
#               k__Bacteria|p__Proteobacteria|c__Gammaproteobacteria|o__Enterobacterales|f__Morganellaceae|g__Proteus|s__Proteus_mirabilis  \
# N2_031_008G1                                                0.0
# N2_031_010G1                                                0.0
#
#               k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Propionibacteriales|f__Propionibacteriaceae|g__Cutibacterium|s__Propionibacterium_namnetense  \
# N2_031_008G1                                                0.0
# N2_031_010G1                                                0.0
#
#               k__Eukaryota|p__Basidiomycota|c__Malasseziomycetes|o__Malasseziales|f__Malasseziaceae|g__Malassezia|s__Malassezia_restricta  \
# N2_031_008G1                                                0.0
# N2_031_010G1                                                0.0
#
#               k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Micrococcales|f__Micrococcaceae|g__Micrococcus|s__Micrococcus_luteus  \
# N2_031_008G1                                                0.0
# N2_031_010G1                                                0.0
#
#               k__Bacteria|p__Actinobacteria|c__Actinobacteria|o__Micrococcales|f__Micrococcaceae|g__Micrococcus|s__Micrococcus_aloeverae  \
# N2_031_008G1                                                0.0
# N2_031_010G1                                                0.0
#
#               Group
# N2_031_008G1      1
# N2_031_010G1      1
#
# [2 rows x 225 columns]
#               UNMAPPED  UNINTEGRATED  \
# N2_031_008G1  0.063191      0.855767
# N2_031_010G1  0.060563      0.858861
#
#               PWY0-1586: peptidoglycan maturation (meso-diaminopimelate containing)  \
# N2_031_008G1                                           0.001267
# N2_031_010G1                                           0.001246
#
#               PWY-1042: glycolysis IV (plant cytosol)  \
# N2_031_008G1                                 0.001178
# N2_031_010G1                                 0.001153
#
#               PWY-7111: pyruvate fermentation to isobutanol (engineered)  \
# N2_031_008G1                                           0.000841
# N2_031_010G1                                           0.000857
#
#               PWY-7013: L-1,2-propanediol degradation  \
# N2_031_008G1                                 0.000792
# N2_031_010G1                                 0.000841
#
#               PWY-621: sucrose degradation III (sucrose invertase)  \
# N2_031_008G1                                           0.000671
# N2_031_010G1                                           0.000654
#
#               PWY-6936: seleno-amino acid biosynthesis  \
# N2_031_008G1                                  0.000628
# N2_031_010G1                                  0.000601
#
#               SER-GLYSYN-PWY: superpathway of L-serine and glycine biosynthesis I  \
# N2_031_008G1                                           0.000627
# N2_031_010G1                                           0.000662
#
#               ASPASN-PWY: superpathway of L-aspartate and L-asparagine biosynthesis  \
# N2_031_008G1                                           0.000616
# N2_031_010G1                                           0.000589
#
#               ...  PWY-6565: superpathway of polyamine biosynthesis III  \
# N2_031_008G1  ...                                                0.0
# N2_031_010G1  ...                                                0.0
#
#               PWY-6572: chondroitin sulfate degradation I (bacterial)  \
# N2_031_008G1                                                0.0
# N2_031_010G1                                                0.0
#
#               PWY-7312: dTDP-D-&beta;-fucofuranose biosynthesis  \
# N2_031_008G1                                                0.0
# N2_031_010G1                                                0.0
#
#               PWY-6478: GDP-D-glycero-&alpha;-D-manno-heptose biosynthesis  \
# N2_031_008G1                                                0.0
# N2_031_010G1                                                0.0
#
#               PWY-6992: 1,5-anhydrofructose degradation  \
# N2_031_008G1                                        0.0
# N2_031_010G1                                        0.0
#
#               PWY66-201: nicotine degradation IV  \
# N2_031_008G1                                 0.0
# N2_031_010G1                                 0.0
#
#               PWY-7626: bacilysin biosynthesis  \
# N2_031_008G1                               0.0
# N2_031_010G1                               0.0
#
#               PWY-6876: isopropanol biosynthesis  \
# N2_031_008G1                                 0.0
# N2_031_010G1                                 0.0
#
#               PWY-3502: superpathway of NAD biosynthesis in eukaryotes  Group
# N2_031_008G1                                                0.0             1
# N2_031_010G1                                                0.0             1
#
# [2 rows x 481 columns]

# %%
selector = []
caliper, ratio=(0.1, 1)
params = [('output', 'output_dir', '../Temp/'+pi+'/'), ('psm', 'caliper', str(caliper)), ('psm', 'ratio', str(ratio))]
params
# Out:
# [('output', 'output_dir', '../Temp/08/'),
#  ('psm', 'caliper', '0.1'),
#  ('psm', 'ratio', '1')]

# %%
key_bf=[ '97', '98', '99_1', '99_2', '99_3', '100', '101']
project_bf= dict([(key,projects[key]) for key in key_bf])
print(project_bf)
# Out:
# {'97': ['YuJ_2015', 'stool', 'control', 'CRC'], '98': ['ZeeviD_2015', 'stool', 'control', nan], '99_1': ['ZellerG_2014', 'stool', 'control', 'adenoma'], '99_2': ['ZellerG_2014', 'stool', 'control', 'CRC'], '99_3': ['ZellerG_2014', 'stool', 'CRC', 'adenoma'], '100': ['ZhuF_2020', 'stool', 'control', 'schizofrenia'], '101': ['NagySzakalD_2017', 'stool', 'control', 'ME/CFS']}
